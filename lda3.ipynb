# %%
import guidedlda
import json
import numpy as np
import glob
import pandas as pd
import re
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from stanfordcorenlp import StanfordCoreNLP
from corextopic import corextopic as ct
import scipy.sparse as ss
from scipy import spatial

TOPIC_NUMS_TUPLE = (50,)
ITERATION_NUMS = 200
TOP_K_WORDS = 25
TOP_K_DOC = 10
SEED_CONFIDENCE = 0.99
CACHE = True
DATA_PATH = 'data/'
WORD = 'word/'
CAMPAIGNS = 'campaigns/'
TRANSCRIPTIONS = 'transcriptions/'
OCR = 'ocr/'
CLEAN_DATA = 'clean_data/'
COMBINE_DATA = 'combine_data/'

STOP_WORDS_FILE_PATH = DATA_PATH + WORD + 'stop_word_list.txt'
SEED_WORDS_FILE_PATH = DATA_PATH + WORD + 'seed_word.txt'

CAMPAIGN_FILE_PATH = DATA_PATH + CAMPAIGNS
CAMPAIGN_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_campaign.txt'
RAW_CAMPAIGN_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_raw_campaign.json'

TRANSCRIPTION_FILE_PATH = DATA_PATH + TRANSCRIPTIONS
TRANSCRIPTION_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_transcription.txt'
RAW_TRANSCRIPTION_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_raw_transcription.json'

COMBINATION_DATA_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_combination.txt'
RAW_COMBINATION_DATA_CACHE_FILE = DATA_PATH + CLEAN_DATA + '_raw_combination.json'

OCR_FILE_PATH = DATA_PATH + OCR

LOADING_COLUMN = ['DesTopicTeamLoading', 'DesTopicProductLoading', 'DesTopicMotivationLoading', 'DesTopicRewardLoading',
                  'NarTopicTeamLoading', 'NarTopicProductLoading', 'NarTopicMotivationLoading', 'NarTopicRewardLoading',
                  'Consistency']


# combine_data the campaign and narratives together and re-run the model
# compute the cosine similarity for the document_topic between the campaign and narrative

def main():
    X, word2id, vocab = load_data('transcription')
    seed_topic_list = load_seed_words()
    loglikelihoods = []
    # seed_word_count(X, word2id, seed_topic_list)
    # top_k_word(X, 30, vocab)
    for topic_num in TOPIC_NUMS_TUPLE:
        model = guided_analysis(X, word2id, topic_num, SEED_CONFIDENCE, seed_topic_list)
        # model = non_guided_analysis(X, topic_num)
        loglikelihoods.append(model.loglikelihood())
        retrieve_words_from(model, vocab, topic_num, TOP_K_WORDS)
        # calculate_loading(model, topic_num, seed_topic_list)
        # export_seeds_assignment(model, word2id, topic_num, seed_topic_list)
    plt.plot(list(TOPIC_NUMS_TUPLE), loglikelihoods)
    plt.show()


def run_corextopic():
    X, word2id, vocab = load_data('campaign')
    seed_topic_list = load_seed_words()
    model = corextopic_analysis(X, vocab, word2id, 50, seed_topic_list)
    doc_topic = model.p_y_given_x
    for doc_id in range(10):
        row = []
        for topic_id in range(4):
            row.append(doc_topic[doc_id][topic_id])
        print(row)
    topics = model.get_topics(topic=0, n_words=25)
    print(topics)


def export_loading():
    seed_topic_list = load_seed_words()
    X, word2id, vocab = load_data('combination')
    model = guided_analysis(X, word2id, 150, SEED_CONFIDENCE, seed_topic_list)
    calculate_loading(model, 150, seed_topic_list)
    export_loading_to_excel(model, seed_topic_list)


def guided_analysis(X, word2id, topic_num, confidence, seed_topic_list):
    """
    Guided Analysis on the given dtm
    """
    model = guidedlda.GuidedLDA(n_topics=topic_num, n_iter=ITERATION_NUMS, random_state=7, refresh=20)
    model.fit(X, seed_topics=load_seed_topics(word2id, seed_topic_list), seed_confidence=confidence)
    return model


def non_guided_analysis(X, topic_num):
    """
    Non_guided Analysis on the given dtm
    """
    model = guidedlda.GuidedLDA(n_topics=topic_num, n_iter=ITERATION_NUMS, random_state=7, refresh=20)
    model.fit(X)
    return model


def corextopic_analysis(X, vocab, word2id, topic_num, seed_topic_list):
    model = ct.Corex(n_hidden=topic_num, max_iter=200)
    seed_words = [[word for word in words if word in word2id.keys()] for words in seed_topic_list.values()]
    model.fit(ss.csr_matrix(X), words=vocab, anchors=seed_words, anchor_strength=4)
    return model


def calculate_loading(model, topic_num, seed_topic_list, n_top_docs=TOP_K_DOC, human_readable=False, sorting=False):
    """
    Export the loading for the model
    """
    doc_topic = model.doc_topic_
    doc_num = doc_topic.shape[0]
    result = []
    seed_topic_num = len(seed_topic_list.keys())
    if sorting:
        sorted_index = np.argsort(doc_topic, axis=0)  # sort the data with index row by row
        loading_set = range(doc_num - 1, doc_num - n_top_docs - 1, -1)
        if human_readable:
            data_list = read_json(RAW_CAMPAIGN_CACHE_FILE)
            campaigns = [' '.join(project['ProjectCampaign']).replace('\n', '') for project in data_list]
        else:
            campaigns = read_file(CAMPAIGN_CACHE_FILE)
        for topic_id in range(seed_topic_num):
            result.append("--------- Topic {} ---------".format(topic_id))
            for ranking in loading_set:
                doc_id = sorted_index[ranking, topic_id]
                result.append(
                    "Document {} {} : {}".format(doc_id, format_digit(doc_topic[doc_id, topic_id]), campaigns[doc_id]))
    else:
        result.append("              {}".format(" ".join(["Topic " + str(i) for i in range(seed_topic_num)])))
        for doc_id in range(10):
            result.append("Document {} : {}".format(str(doc_id), " ".join(
                ["  " + str(format_digit(doc_topic[doc_id][topic_id])) for topic_id in range(seed_topic_num)])))
    save_file(result, topic_num, 'document_loading')


def seed_word_count(X, word2id, seed_topic_list):
    word_frequence = np.sum(X, axis=0)
    result = []
    for tid, words in enumerate(seed_topic_list.values()):
        word_count = {}
        for word in words:
            if word in word2id.keys():
                word_count[word] = word_frequence[word2id[word]]
            else:
                word_count[word] = 0
        result.append(pretty_print_loading(tid, word_count.keys(), word_count.values()))
    save_file(result, '', 'seed_wordcount')


def top_k_word(X, top_k, vocab):
    word_frequence = np.sum(X, axis=0)
    word_index = np.argsort(word_frequence)[:-(top_k + 1): -1]
    word_count = word_frequence[word_index]
    word_list = [vocab[i] for i in word_index]
    print(
        'Top-k frequent word: {}'.format(','.join(
            list(map(lambda x, y: str(x) + '(' + str(format_digit(y)) + ')', word_list, word_count)))))


def retrieve_words_from(model, vocab, topic_num, n_top_words):
    """
    Retrieve the top k topics
    """
    topic_word = model.topic_word_
    result = []
    for tid, topic_dist in enumerate(topic_word):
        word_index = np.argsort(topic_dist)[:-(n_top_words + 1): -1]
        topic_words = np.array(vocab)[word_index]
        topic_words_assignment = topic_dist[word_index]
        result.append(pretty_print_loading(tid, topic_words, topic_words_assignment))
    save_file(result, topic_num, 'topic_words_matrix')


def pretty_print_loading(tid, topic_words, topic_words_assignment):
    return 'Topic {} : {}'.format(tid, ','.join(
        list(map(lambda x, y: str(x) + '(' + str(format_digit(y)) + ')', topic_words, topic_words_assignment))))


def export_seeds_assignment(model, word2id, topic_num, seed_topic_list):
    topic_word = model.topic_word_
    result = []
    for tid, seeds in enumerate(seed_topic_list.values()):
        loading = {}
        for word in seeds:
            if word in word2id.keys():
                loading[word] = topic_word[tid][word2id[word]]
            else:
                loading[word] = 0
        result.append(pretty_print_loading(tid, loading.keys(), loading.values()))
    save_file(result, topic_num, 'seeds_loading')


def export_loading_to_excel(model, seed_topic_list):
    data_list = read_campaigns_from_path(CAMPAIGN_FILE_PATH)

    des_data_list = read_json(RAW_CAMPAIGN_CACHE_FILE)
    nar_data_list = read_json(RAW_TRANSCRIPTION_CACHE_FILE)

    des_pid2doc = {}
    nar_pid2doc = {}

    des_doc_num = len(des_data_list)
    des_doc_topic = model.doc_topic_[0: des_doc_num, :]
    nar_doc_topic = model.doc_topic_[des_doc_num: , :]
    column_num = len(LOADING_COLUMN)
    seed_topic_num = len(seed_topic_list.keys())
    output_data = {}
    keys = ['ProjectID'] + LOADING_COLUMN
    # initialize rows for excel
    for doc_id in range(len(data_list)):
        project_id = data_list[doc_id]['ProjectId']
        row = [project_id] + [0.0] * column_num
        output_data[project_id] = row
    i = 0
    # setting campaign loading
    for doc_id in range(des_doc_topic.shape[0]):
        project_id = des_data_list[doc_id]['ProjectId']
        des_pid2doc[project_id] = doc_id
        if project_id in output_data.keys():
            i += 1
            for topic_id in range(seed_topic_num):
                output_data[project_id][topic_id + 1] = float(format_digit(des_doc_topic[doc_id][topic_id]))
    print("Total descriptions: " + str(i))
    i = 0
    # setting transcription loading and consistency
    for doc_id in range(nar_doc_topic.shape[0]):
        project_id = nar_data_list[doc_id]['id']
        nar_pid2doc[project_id] = doc_id
        if project_id in output_data.keys():
            i += 1
            for topic_id in range(seed_topic_num):
                output_data[project_id][5 + topic_id] = float(format_digit(nar_doc_topic[doc_id][topic_id]))

    for doc_id in range(len(data_list)):
        project_id = data_list[doc_id]['ProjectId']
        if project_id in nar_pid2doc.keys() and project_id in des_pid2doc.keys():
            des_loading = des_doc_topic[des_pid2doc[project_id]]
            nar_loading = nar_doc_topic[nar_pid2doc[project_id]]
            output_data[project_id][9] = float(
                format_digit(1 - spatial.distance.cosine(des_loading, nar_loading)))
    print("Total transcriptions: " + str(i))
    pd.DataFrame(output_data.values()).to_excel('loading.xlsx', header=keys, index=False)


def dt_matrix(model, n_top_docs, topic_num):
    """
    Export the document - topic matrix
    """
    doc_topic = model.doc_topic_
    result = []
    for i, docs_dist in enumerate(doc_topic):
        doc_topic_assignment = np.sort(docs_dist)[: -(n_top_docs + 1): -1]
        result.append('Document {} : {}'.format(i, ','.join(map(str, doc_topic_assignment))))
    save_file(result, topic_num, 'document_topic_matrix')


def tw_matrix(model, n_top_words, topic_num):
    """
    Export the topic- word matrix
    """
    topic_word = model.topic_word_
    result = []
    for i, word_dist in enumerate(topic_word):
        topic_word_assignment = np.sort(word_dist)[: -(n_top_words + 1): - 1]
        result.append('Topic {} : {}'.format(i, ','.join(map(str, topic_word_assignment))))
    save_file(result, topic_num, 'topic_word_matrix')


def unique_words(model, vocab, n_top_words, topic_num):
    """
    Find out the unique words for the topics
    """
    word_topic = model.word_topic_
    result = []
    for i, topic_dist in enumerate(word_topic):
        beta_dist = np.array(list(map(lambda x: float(x) / (1 - x), topic_dist)))
        # pick n_top beta for the words in the topic
        sorted_index = np.argsort(beta_dist)[: -(n_top_words + 1): - 1]
        sorted_beta = beta_dist[sorted_index]
        result.append(('{} : {}'.format(vocab[i], ','.join(
            list(map(lambda x, y: str(x) + '(' + str(y) + ')', sorted_index, sorted_beta))))))
    save_file(result, topic_num, 'word_uniqueness_matrix')


def load_seed_topics(word2id, seed_topic_list):
    """
    Construct the seeds_topic dictionary
    :param word2id:
    :return:
    """
    seed_topics = {}
    for tid, seeds in enumerate(seed_topic_list.values()):
        for word in seeds:
            lower_word = word.lower()
            if lower_word in word2id.keys():
                seed_topics[word2id[lower_word]] = tid
    return seed_topics


def format_digit(input):
    return '{0:.3f}'.format(input)


def get_wordnet_pos(treebank_tag):
    """
    get part of speech from tree bank ag
    """
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN


def load_stopwords(filepath):
    """
    Load the stop words
    """
    stop_words = set(stopwords.words('english'))
    with open(filepath) as fp:
        for line in fp:
            stop_words.add(line.rstrip('\n'))
    return stop_words


def load_seed_words():
    """
    Load the seed words
    """
    word_list = read_file(SEED_WORDS_FILE_PATH)
    word_dict = {}
    for tid, words in enumerate(word_list):
        word_dict[tid] = [word.strip() for word in words.split(',')]
    return word_dict


def filter_words(tokens, stop_words):
    """
    filter the word by nltk stopwords and length
    """
    return [w for w in tokens if w not in stop_words and len(w) > 3]


def clean_text(text):
    text = re.sub(r"\S*@\S*", " ", text)  # remove email address
    text = re.sub(r"((:?http|https)://)?[-./?:@_=#\w]+\.(?:[a-zA-Z]){2,6}(?:[-\w.&/?:@_=#()])*", " ",
                  text)  # remove urls
    text = re.sub(r"[-!?=~|#$+%*&@:/(){}\[\],\"\n'._]", " ", text)  # remove punctuations
    text = re.sub(r"\d+", " ", text)  # remove digits
    text = re.sub(r"\b(\w)\1+\b", " ", text)  # remove meaningless word composed

    return text


def nltk_lemmatize(campaign_list):
    """
    Return the campaign list after being lemmatized
    """
    result = []
    wordnet_lemmatizer = nltk.WordNetLemmatizer()
    stop_words = load_stopwords(STOP_WORDS_FILE_PATH)
    for campaign in campaign_list:
        token_list = []
        tokens = filter_words(nltk.word_tokenize(campaign, language='english'), stop_words)
        pos_tags = nltk.pos_tag(tokens)
        for word, tag in pos_tags:
            token_list.append(wordnet_lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag)))
        result.append(" ".join(token_list))
    return result


def stanford_lemmatize(campaign_list):
    """
    Return the campaign list after being lemmatized by stanford nlp
    """
    result = []
    nlp = StanfordCoreNLP(path_or_host='http://localhost', port=9000, timeout=30000)
    stop_words = load_stopwords(STOP_WORDS_FILE_PATH)

    # Define properties needed to get lemma
    props = {'annotators': 'pos,lemma',
             'pipelineLanguage': 'en',
             'outputFormat': 'json'}
    for campaign in campaign_list:
        parsed_str = nlp.annotate(campaign, properties=props)
        parsed_dict = json.loads(parsed_str)
        sen_len = len(parsed_dict['sentences'])
        if sen_len == 0:
            result.append("")
        elif sen_len == 1:
            lemma_tokens = [token['lemma'] for token in parsed_dict['sentences'][0]['tokens']]
            filtered_list = filter_words(lemma_tokens, stop_words)
            result.append(' '.join(filtered_list))
        else:
            print("Length of sentence of lemmatization is greater than 1 ")
    return result


# * -------------- Utils function ------------ *


# def save_file(data, topic_num, filename):
#     with open('%s_%s.txt' % (str(topic_num), filename), 'w') as fp:
#         for item in data:
#             fp.write(item + "\n")
#         fp.close()


def save_file(data, topic_num, filename):
    for item in data:
        print(item)


def save_cache_file(data, filename):
    with open(filename, 'w') as fp:
        for item in data:
            fp.write(item + "\n");
        fp.close()


def read_file(filename):
    with open(filename, 'r') as fp:
        data_list = [line.rstrip('\n') for line in fp]
        fp.close()
    return data_list


def read_json(filename):
    with open(filename, 'r') as fp:
        data_list = list(json.load(fp))
        fp.close()
    return data_list


def read_campaigns_from_path(path):
    duplicate_data = []
    for file_name in [f for f in glob.glob(path + "**/*.json", recursive=True)]:
        duplicate_data.extend(read_json(file_name))
    # apply filtering for the data
    data_list = {}
    for item in duplicate_data:
        pid = item['ProjectId']
        if pid not in data_list.keys():
            data_list[pid] = item
    return list(data_list.values())


def dump_json(data, filename):
    with open(filename, 'w') as fp:
        json.dump(data, fp)
        fp.close()


def format_str(input):
    return re.sub(r'[^\x00-\x7F]+', ' ', str(input.encode('utf-8')).strip())


def read_transcription(filename):
    df = pd.read_excel(filename, sheet_name='results')
    data = []
    ids = df['id'].values
    transcriptions = df['transcription'].values
    for index in range(df.shape[0]):
        project = {'id': str(ids[index]),
                   'transcription': '' if pd.isna(transcriptions[index]) else format_str(str(transcriptions[index]))}
        data.append(project)
    return data


def read_transcriptions_from_path(path):
    pid_set = set()
    data = []
    for file_name in [f for f in glob.glob(path + "**/*.xlsx", recursive=True)]:
        for project in read_transcription(file_name):
            if project['id'] not in pid_set:
                data.append(project)
                pid_set.add(project['id'])
    return data


def read_ocr_text(filename):
    data_list = []
    with open(filename, 'r') as fp:
        data_json = json.load(fp)
        for pid in data_json.keys():
            data_list.append({'id': pid, 'ocr_text': " ".join(data_json[pid])})
    return data_list


def read_ocr_texts_from_path(path):
    data_list = []
    pid_set = set()
    for file_name in [f for f in glob.glob(path + "**/*.json", recursive=True)]:
        for project in read_ocr_text(file_name):
            if project['id'] not in pid_set:
                data_list.append(project)
                pid_set.add(project['id'])
    return data_list


def combine(campaign_list, ocr_text_list):
    pid2index = {}
    for index, project in enumerate(campaign_list):
        pid2index[project['ProjectId']] = index
    for project in ocr_text_list:
        pid = project['id']
        if pid in pid2index.keys():
            campaign_list[pid2index[pid]]['ProjectCampaign'].append(project['ocr_text'])
        else:
            print("ERROR: ocr text with id doesn't exist in the campaign")
    return campaign_list


def get_cleaned_campaign(data_list):
    return [clean_text((" ".join(item['ProjectCampaign'])).lower()) for item in data_list]


def get_cleaned_transcription(data_list):
    return [clean_text(item['transcription'].lower()) for item in data_list]


def load_data(doc_type):
    """
    1. Load the data from file
    2. clean the text
    3. lemmatize the text
    4. extract the vocabulary from the documents
    5. convert the data to document - term matrix
    """
    document_list = []
    raw_document_list = []
    if doc_type == 'campaign':
        if CACHE:
            document_list = read_file(CAMPAIGN_CACHE_FILE)
        else:
            campaign_data_list = read_campaigns_from_path(CAMPAIGN_FILE_PATH)
            ocr_data_list = read_ocr_texts_from_path(OCR_FILE_PATH)
            data_list = combine(campaign_data_list, ocr_data_list)
            if data_list:
                cleaned_list = get_cleaned_campaign(data_list)
                lemmatized_list = stanford_lemmatize(cleaned_list)
                # lemmatized_list = nltk_lemmatize(cleaned_list)
                for i, campaign in enumerate(lemmatized_list):
                    if len(campaign) > 0:
                        document_list.append(campaign)
                        raw_document_list.append(data_list[i])
                save_cache_file(document_list, CAMPAIGN_CACHE_FILE)
                dump_json(raw_document_list, RAW_CAMPAIGN_CACHE_FILE)
    elif doc_type == 'transcription':
        if CACHE:
            document_list = read_file(TRANSCRIPTION_CACHE_FILE)
        else:
            data_list = read_transcriptions_from_path(TRANSCRIPTION_FILE_PATH)
            cleaned_list = get_cleaned_transcription(data_list)
            lemmatized_list = stanford_lemmatize(cleaned_list)
            for i, transcription in enumerate(lemmatized_list):
                if len(transcription) > 0:
                    document_list.append(transcription)
                    raw_document_list.append(data_list[i])
            save_cache_file(document_list, TRANSCRIPTION_CACHE_FILE)
            dump_json(raw_document_list, RAW_TRANSCRIPTION_CACHE_FILE)
    elif doc_type == 'combination':
        if CACHE:
            document_list = read_file(COMBINATION_DATA_CACHE_FILE)
        else:
            campaign_data_list = combine(read_campaigns_from_path(CAMPAIGN_FILE_PATH),
                                         read_ocr_texts_from_path(OCR_FILE_PATH))
            transcription_data_list = read_transcriptions_from_path(TRANSCRIPTION_FILE_PATH)
            data_list = campaign_data_list + transcription_data_list
            cleaned_list = get_cleaned_campaign(campaign_data_list) + get_cleaned_transcription(transcription_data_list)
            lemmatized_list = stanford_lemmatize(cleaned_list)
            for i, document in enumerate(lemmatized_list):
                if len(document) > 0:
                    document_list.append(document)
                    raw_document_list.append(data_list[i])
            save_cache_file(document_list, COMBINATION_DATA_CACHE_FILE)
            dump_json(raw_document_list, RAW_COMBINATION_DATA_CACHE_FILE)
    vectorizer = CountVectorizer(stop_words=None, ngram_range=(1, 1),
                                 lowercase=True, analyzer='word')
    X = vectorizer.fit_transform(document_list).toarray()
    word2id = vectorizer.vocabulary_
    vocab = vectorizer.get_feature_names()
    return X, word2id, vocab

# %%
# Supervised Analysis
X, word2id, vocab = load_data('transcription')
seed_topic_list = load_seed_words()
model = guided_analysis(X, word2id, 50, SEED_CONFIDENCE, seed_topic_list)
retrieve_words_from(model, vocab, 50, TOP_K_WORDS)
# Out:
# INFO:guidedlda:n_documents: 412
# INFO:guidedlda:vocab_size: 7526
# INFO:guidedlda:n_words: 49869
# INFO:guidedlda:n_topics: 50
# INFO:guidedlda:n_iter: 200
# INFO:guidedlda:<0> log likelihood: -685577
# INFO:guidedlda:<20> log likelihood: -438722
# INFO:guidedlda:<40> log likelihood: -429206
# INFO:guidedlda:<60> log likelihood: -425388
# INFO:guidedlda:<80> log likelihood: -422836
# INFO:guidedlda:<100> log likelihood: -421444
# INFO:guidedlda:<120> log likelihood: -420197
# INFO:guidedlda:<140> log likelihood: -418658
# INFO:guidedlda:<160> log likelihood: -417860
# INFO:guidedlda:<180> log likelihood: -417155
# INFO:guidedlda:<199> log likelihood: -416863
# Topic 0 : build(0.023),create(0.022),people(0.021),community(0.020),help(0.020),part(0.020),give(0.019),team(0.019),work(0.018),skill(0.017),learn(0.016),place(0.015),development(0.013),thank(0.012),role(0.011),feel(0.010),experience(0.010),talk(0.010),develop(0.009),social(0.009),issue(0.008),raise(0.008),grow(0.007),system(0.007),idea(0.007)
# Topic 1 : card(0.116),start(0.018),turn(0.017),deck(0.015),friend(0.014),hand(0.012),choose(0.012),help(0.012),character(0.011),easy(0.010),round(0.009),come(0.009),board(0.009),work(0.008),rule(0.008),draw(0.008),thank(0.007),action(0.007),give(0.007),simple(0.007),family(0.007),type(0.006),pick(0.006),attack(0.006),number(0.006)
# Topic 2 : help(0.027),come(0.024),people(0.022),story(0.018),book(0.018),thing(0.017),find(0.015),think(0.015),love(0.012),thank(0.012),back(0.012),bring(0.012),world(0.012),tell(0.011),hope(0.011),check(0.011),call(0.011),actually(0.010),page(0.010),kind(0.010),idea(0.010),tabletop(0.010),work(0.009),support(0.009),role(0.009)
# Topic 3 : level(0.022),create(0.022),design(0.021),work(0.018),base(0.016),world(0.014),love(0.014),thing(0.014),support(0.013),reward(0.012),look(0.012),bring(0.012),great(0.011),campaign(0.010),character(0.010),fund(0.010),early(0.009),offer(0.008),share(0.008),unique(0.008),back(0.008),explore(0.008),community(0.008),quality(0.008),product(0.007)
# Topic 4 : unit(0.030),dice(0.027),technology(0.027),digital(0.020),command(0.018),enemy(0.015),bike(0.015),physical(0.012),edition(0.012),defeat(0.012),cyber(0.012),invader(0.010),control(0.010),universe(0.010),clash(0.010),battle(0.008),highly(0.008),vorpal(0.008),city(0.008),star(0.008),corrupt(0.008),exclusive(0.008),listen(0.008),move(0.008),lord(0.008)
# Topic 5 : world(0.066),ability(0.024),combat(0.023),build(0.020),storm(0.018),core(0.016),create(0.016),expand(0.014),faction(0.013),destroy(0.013),open(0.012),depth(0.012),develop(0.012),expansion(0.012),colony(0.011),experience(0.010),gameplay(0.010),city(0.009),gear(0.009),military(0.009),mining(0.008),character(0.008),planet(0.008),lead(0.008),earth(0.008)
# Topic 6 : control(0.034),kill(0.023),move(0.023),domino(0.019),spell(0.019),weapon(0.019),boss(0.018),respect(0.015),consequence(0.015),money(0.015),side(0.015),damage(0.014),item(0.013),mafioso(0.011),gain(0.011),maybe(0.011),start(0.011),fight(0.011),remember(0.011),turn(0.011),fish(0.010),raid(0.010),call(0.009),important(0.009),straight(0.009)
# Topic 7 : module(0.028),number(0.028),location(0.024),design(0.023),list(0.023),space(0.023),matter(0.020),area(0.020),relic(0.016),phase(0.016),generation(0.015),entire(0.015),family(0.013),specifically(0.013),dark(0.011),lgbtq(0.011),sort(0.010),horror(0.010),dining(0.010),intend(0.010),exploration(0.008),mist(0.008),state(0.008),desire(0.008),side(0.008)
# Topic 8 : shadow(0.038),dungeon(0.036),character(0.031),give(0.024),arena(0.019),weapon(0.017),hero(0.017),adventure(0.016),piece(0.015),spell(0.015),style(0.015),choice(0.013),guide(0.012),builder(0.012),break(0.011),handbook(0.011),strategy(0.009),minion(0.009),competition(0.008),group(0.008),cloud(0.008),power(0.008),exist(0.008),sword(0.008),imagine(0.008)
# Topic 9 : video(0.045),thing(0.028),think(0.024),give(0.022),back(0.020),show(0.020),look(0.019),hope(0.019),people(0.019),character(0.018),live(0.016),create(0.016),watch(0.016),friend(0.014),money(0.012),stuff(0.012),mean(0.012),pick(0.011),walk(0.011),come(0.011),question(0.011),work(0.010),sure(0.010),pretty(0.009),thanks(0.009)
# Topic 10 : deck(0.037),gold(0.025),custom(0.018),piece(0.016),thank(0.015),photo(0.015),cook(0.015),collector(0.015),product(0.015),collect(0.015),mythology(0.013),restaurant(0.013),valuable(0.013),back(0.012),commodity(0.012),display(0.012),moon(0.012),create(0.012),trade(0.010),collection(0.010),present(0.010),thousand(0.010),health(0.010),cooking(0.009),rich(0.009)
# Topic 11 : ship(0.065),crew(0.037),cannon(0.023),captain(0.023),move(0.018),pirate(0.017),protect(0.015),come(0.013),enemy(0.013),save(0.013),fleet(0.013),proteus(0.012),strategy(0.012),member(0.012),island(0.010),cannonball(0.010),gunpowder(0.010),sail(0.010),green(0.010),plenty(0.010),lattice(0.010),beginner(0.010),life(0.008),bilge(0.008),pump(0.008)
# Topic 12 : book(0.032),campaign(0.020),great(0.020),create(0.019),star(0.016),horror(0.016),dark(0.015),start(0.015),write(0.013),realm(0.013),vampire(0.012),system(0.012),darkness(0.011),primo(0.011),fiction(0.011),side(0.011),module(0.009),secret(0.009),avatar(0.009),evil(0.009),expansion(0.009),matter(0.009),hole(0.008),film(0.008),society(0.008)
# Topic 13 : place(0.034),tell(0.027),happen(0.027),shirt(0.024),adventure(0.024),week(0.021),provide(0.020),space(0.019),king(0.019),environment(0.015),close(0.015),work(0.012),battle(0.012),weird(0.011),level(0.011),sword(0.011),bird(0.011),large(0.011),playground(0.011),folk(0.009),north(0.009),esport(0.009),comic(0.009),special(0.009),mobius(0.008)
# Topic 14 : witness(0.035),experience(0.035),category(0.026),virtual(0.022),date(0.021),question(0.019),immersive(0.019),chad(0.016),solution(0.015),location(0.015),answer(0.015),reality(0.015),object(0.013),fighter(0.012),move(0.012),meta(0.012),scenario(0.010),create(0.010),young(0.009),walk(0.009),street(0.009),opportunity(0.009),interaction(0.009),surround(0.009),trick(0.009)
# Topic 15 : back(0.047),draw(0.047),point(0.043),break(0.024),pass(0.023),score(0.018),turn(0.018),person(0.018),meme(0.016),discard(0.016),burrito(0.015),explain(0.013),select(0.013),judge(0.013),school(0.013),amount(0.013),return(0.010),means(0.010),safe(0.010),majority(0.010),sock(0.008),believe(0.008),hall(0.008),predict(0.008),middle(0.008)
# Topic 16 : word(0.037),come(0.034),unicorn(0.031),people(0.028),access(0.017),money(0.017),sleeve(0.014),hear(0.014),campaign(0.014),metaphor(0.014),pledge(0.012),main(0.012),spot(0.012),soon(0.012),creature(0.012),interact(0.011),exclusive(0.011),favorite(0.011),entire(0.011),tournament(0.011),george(0.011),magical(0.011),tear(0.011),subscription(0.009),starter(0.009)
# Topic 17 : action(0.028),space(0.027),point(0.024),resource(0.023),build(0.022),potion(0.022),planet(0.017),monster(0.016),turn(0.015),system(0.015),victory(0.014),shield(0.013),token(0.013),increase(0.012),step(0.012),castle(0.010),gain(0.010),unit(0.010),equipment(0.010),tile(0.010),represent(0.010),energy(0.010),earth(0.010),gold(0.009),choice(0.009)
# Topic 18 : monster(0.084),cave(0.034),tree(0.029),dragon(0.028),tile(0.020),creature(0.016),check(0.016),night(0.015),hill(0.014),full(0.014),note(0.013),thief(0.013),vast(0.013),rock(0.013),place(0.012),terrain(0.012),goblin(0.012),special(0.010),fearsome(0.010),treasure(0.010),tier(0.009),inside(0.009),track(0.008),variety(0.008),forest(0.007)
# Topic 19 : boost(0.061),basketball(0.026),positivity(0.022),increase(0.017),gloom(0.015),composition(0.015),maestro(0.015),positive(0.015),shot(0.015),great(0.015),unique(0.015),performance(0.013),record(0.013),letter(0.013),tube(0.011),soup(0.011),confidence(0.011),require(0.011),shooting(0.009),throne(0.009),negativity(0.009),awesome(0.009),love(0.009),plague(0.009),basket(0.009)
# Topic 20 : escape(0.030),unique(0.020),valley(0.016),nation(0.016),fight(0.014),enjoy(0.013),warlord(0.013),century(0.013),gift(0.012),team(0.012),platform(0.012),inspire(0.012),engine(0.010),experience(0.010),king(0.010),cannabis(0.009),steampunk(0.009),deadly(0.009),mobile(0.009),massive(0.009),arena(0.009),clock(0.007),easter(0.007),technology(0.007),solo(0.007)
# Topic 21 : token(0.075),turn(0.026),crystal(0.025),heart(0.023),move(0.021),show(0.020),allow(0.020),order(0.018),card(0.018),magic(0.017),addition(0.013),series(0.011),place(0.011),stretch(0.011),galaxy(0.010),search(0.010),head(0.010),represent(0.010),draw(0.010),journey(0.010),light(0.009),foil(0.009),bring(0.009),gauntlet(0.009),cube(0.009)
# Topic 22 : board(0.058),people(0.036),come(0.036),look(0.028),move(0.020),convention(0.017),section(0.016),actually(0.016),side(0.016),cool(0.016),friend(0.016),group(0.015),excite(0.014),place(0.013),area(0.013),join(0.011),tabletop(0.011),love(0.010),favorite(0.010),show(0.009),online(0.009),perfect(0.009),platform(0.009),hear(0.009),awesome(0.009)
# Topic 23 : love(0.035),business(0.032),rule(0.024),step(0.021),grow(0.021),actually(0.019),skill(0.017),weapon(0.017),shit(0.017),expertise(0.016),adult(0.016),class(0.016),smash(0.013),loose(0.011),session(0.011),child(0.011),choice(0.011),point(0.011),gain(0.010),represent(0.010),realize(0.010),contribution(0.010),living(0.010),funny(0.010),later(0.008)
# Topic 24 : look(0.036),thing(0.027),kind(0.025),stuff(0.020),back(0.019),cool(0.019),side(0.018),half(0.017),final(0.016),gear(0.016),awesome(0.016),ready(0.014),inside(0.013),pretty(0.013),dungeon(0.013),inch(0.013),come(0.013),edition(0.011),couple(0.011),puzzle(0.011),open(0.010),idea(0.010),upgrade(0.010),find(0.010),hundred(0.010)
# Topic 25 : realm(0.017),fantasy(0.017),write(0.015),ability(0.015),digital(0.014),great(0.012),villain(0.012),enemy(0.012),fable(0.010),grand(0.010),quarterly(0.010),witch(0.010),throw(0.010),awaken(0.008),ride(0.008),park(0.008),critter(0.008),mountain(0.008),merlin(0.008),brain(0.008),timeline(0.008),evil(0.008),thank(0.008),vision(0.008),anime(0.008)
# Topic 26 : podcast(0.033),content(0.022),support(0.019),create(0.018),adventure(0.018),review(0.018),addition(0.016),campaign(0.016),highest(0.016),maze(0.015),form(0.015),quality(0.013),standard(0.012),magazine(0.012),challenge(0.012),solve(0.012),chess(0.010),online(0.010),variety(0.010),guardian(0.009),announce(0.009),wait(0.009),original(0.009),directly(0.009),simple(0.009)
# Topic 27 : ninja(0.077),deck(0.031),back(0.022),tarot(0.020),flip(0.020),moon(0.018),samurai(0.018),space(0.013),wound(0.013),katana(0.013),prison(0.013),draw(0.011),discard(0.011),remove(0.009),thing(0.009),match(0.009),matt(0.009),sort(0.009),help(0.009),dollar(0.009),pawn(0.009),taro(0.009),bind(0.007),prevent(0.007),actual(0.007)
# Topic 28 : mystery(0.047),bird(0.034),interesting(0.024),wonderful(0.022),family(0.022),village(0.022),hear(0.021),life(0.019),fairy(0.017),backyard(0.017),basically(0.017),learn(0.015),sheep(0.013),younger(0.013),symbol(0.011),yeah(0.011),teach(0.011),excite(0.011),older(0.011),police(0.011),description(0.011),attract(0.009),point(0.009),powerful(0.009),market(0.009)
# Topic 29 : yeah(0.033),wild(0.029),thousand(0.029),hundred(0.027),okay(0.024),card(0.024),think(0.022),income(0.021),score(0.021),painting(0.019),stack(0.019),million(0.019),price(0.017),point(0.017),sell(0.017),total(0.016),money(0.015),credit(0.015),number(0.015),taste(0.013),critic(0.013),collector(0.013),artwork(0.012),dollar(0.011),base(0.010)
# Topic 30 : enemy(0.040),island(0.038),city(0.033),target(0.020),range(0.018),attack(0.018),army(0.016),battle(0.015),feature(0.015),allow(0.014),opponent(0.014),control(0.014),resource(0.014),defend(0.014),damage(0.014),shrine(0.013),village(0.011),dorado(0.011),powerful(0.011),wall(0.011),decide(0.010),building(0.010),farm(0.009),strategic(0.009),unique(0.009)
# Topic 31 : deck(0.054),dice(0.037),hold(0.027),campaign(0.027),provide(0.025),design(0.025),solution(0.025),double(0.022),wood(0.022),solve(0.020),problem(0.018),sovereign(0.017),solid(0.015),side(0.015),pledge(0.013),decision(0.012),spread(0.012),layout(0.010),vote(0.010),cube(0.010),essential(0.010),queen(0.008),onslaught(0.008),walnut(0.008),result(0.008)
# Topic 32 : event(0.037),people(0.037),party(0.033),good(0.028),pool(0.025),thing(0.022),actually(0.021),yeah(0.020),sign(0.014),stage(0.014),night(0.014),storm(0.013),food(0.012),wrong(0.011),land(0.011),girl(0.011),tear(0.010),honestly(0.010),company(0.009),giant(0.009),panel(0.009),sundown(0.008),enjoy(0.008),ball(0.008),meet(0.008)
# Topic 33 : yeah(0.047),night(0.034),band(0.025),back(0.021),wall(0.021),good(0.016),leave(0.016),spend(0.014),party(0.014),song(0.014),hold(0.012),roll(0.012),music(0.011),okay(0.011),accessory(0.011),middle(0.011),problem(0.011),totally(0.011),crowd(0.011),sick(0.010),ship(0.010),trip(0.009),funny(0.009),money(0.009),late(0.009)
# Topic 34 : world(0.052),creature(0.040),land(0.020),animal(0.020),unique(0.017),rescue(0.015),travel(0.014),light(0.014),bring(0.013),earth(0.013),epic(0.012),exist(0.012),spirit(0.012),species(0.011),save(0.011),terrain(0.009),mission(0.009),meaning(0.009),canvas(0.009),famous(0.008),capture(0.007),deep(0.007),wayfarer(0.007),faraway(0.007),water(0.007)
# Topic 35 : puzzle(0.074),movie(0.052),piece(0.031),world(0.031),room(0.029),henry(0.022),republican(0.015),great(0.015),catch(0.013),terrain(0.013),start(0.013),pledge(0.013),regulation(0.011),functional(0.011),date(0.009),beautiful(0.009),trap(0.009),jump(0.009),wear(0.007),universe(0.007),free(0.007),incredible(0.007),minute(0.007),newest(0.007),summon(0.007)
# Topic 36 : life(0.046),artist(0.041),show(0.031),head(0.022),back(0.019),body(0.019),paint(0.018),force(0.016),playable(0.016),welcome(0.015),dead(0.015),rest(0.013),death(0.012),powerful(0.010),suit(0.010),march(0.010),trait(0.009),serpent(0.009),manage(0.009),trio(0.009),spend(0.009),ship(0.007),foam(0.007),alive(0.007),draft(0.007)
# Topic 37 : face(0.035),drink(0.035),challenge(0.034),brain(0.022),doodle(0.021),point(0.019),night(0.018),product(0.015),stress(0.013),life(0.012),birthday(0.012),sell(0.012),scenario(0.010),nurse(0.010),wall(0.010),boring(0.010),sale(0.010),silly(0.009),program(0.009),engage(0.009),secret(0.007),body(0.007),tonight(0.007),limit(0.007),wife(0.007)
# Topic 38 : sport(0.066),fantasy(0.049),race(0.027),score(0.023),start(0.020),ravenscroft(0.018),join(0.018),family(0.018),woman(0.016),provide(0.016),competition(0.014),note(0.014),track(0.012),speed(0.012),member(0.010),tire(0.010),athlete(0.010),platform(0.010),racer(0.010),professional(0.010),team(0.008),female(0.008),fully(0.008),engagement(0.008),manner(0.008)
# Topic 39 : power(0.057),point(0.025),bear(0.018),human(0.018),quest(0.018),dark(0.017),begin(0.017),steal(0.016),score(0.016),come(0.016),land(0.014),role(0.014),home(0.013),victory(0.013),worth(0.012),dino(0.010),revenge(0.010),greatest(0.009),offer(0.009),avoid(0.009),create(0.009),studio(0.009),unlock(0.009),round(0.009),humanity(0.008)
# Topic 40 : guess(0.028),martin(0.023),word(0.021),language(0.018),sheet(0.018),pretty(0.016),voice(0.014),oracle(0.014),okay(0.014),kick(0.014),fall(0.014),white(0.012),valhalla(0.011),decide(0.009),read(0.009),noise(0.009),common(0.009),image(0.009),penis(0.009),reading(0.009),dick(0.009),astrology(0.009),hope(0.009),giggle(0.009),girth(0.007)
# Topic 41 : dice(0.110),roll(0.041),call(0.037),robot(0.019),content(0.016),ocean(0.015),chapter(0.014),continue(0.014),power(0.012),place(0.012),customer(0.012),kill(0.012),fire(0.012),magical(0.012),free(0.011),teacher(0.011),meal(0.011),complete(0.011),drink(0.010),welcome(0.009),massive(0.009),inside(0.009),decide(0.009),ruler(0.007),earn(0.007)
# Topic 42 : store(0.035),cover(0.030),company(0.027),donate(0.026),help(0.018),golf(0.014),kitty(0.014),critical(0.014),finish(0.012),back(0.012),allow(0.012),panda(0.011),succeed(0.011),country(0.011),seek(0.011),training(0.011),giant(0.009),expansion(0.009),baby(0.009),takenoko(0.009),sasquatch(0.009),noble(0.009),organization(0.009),secure(0.008),struggle(0.008)
# Topic 43 : table(0.064),great(0.032),back(0.029),attach(0.018),place(0.016),field(0.016),miniature(0.016),build(0.014),stand(0.014),town(0.014),come(0.012),call(0.012),help(0.012),piece(0.010),lose(0.010),flock(0.010),grab(0.009),find(0.009),battlefield(0.009),remove(0.008),easily(0.008),water(0.008),bottle(0.008),fall(0.008),drop(0.008)
# Topic 44 : color(0.036),board(0.032),black(0.030),chicken(0.026),wood(0.023),white(0.023),blue(0.021),cheap(0.019),follower(0.019),dice(0.017),pick(0.015),yellow(0.015),come(0.015),erase(0.011),king(0.009),leader(0.009),brown(0.009),excite(0.009),claim(0.009),throne(0.009),super(0.009),chris(0.009),purple(0.008),agent(0.008),merchant(0.008)
# Topic 45 : power(0.034),actually(0.032),major(0.026),ally(0.026),world(0.026),stamp(0.020),represent(0.016),american(0.016),famous(0.016),battle(0.014),victory(0.014),fight(0.014),france(0.012),russian(0.012),treatment(0.010),japan(0.010),axis(0.010),state(0.010),suicide(0.010),germany(0.010),conflict(0.008),atomic(0.008),fourth(0.008),unprecedented(0.008),leader(0.008)
# Topic 46 : story(0.034),hero(0.029),battle(0.019),king(0.015),goat(0.013),beat(0.013),defeat(0.013),collection(0.013),victory(0.011),forest(0.011),call(0.011),mode(0.011),gameplay(0.010),guild(0.010),avoid(0.010),beautiful(0.010),adventurer(0.010),solo(0.010),town(0.008),leave(0.008),fame(0.008),overcome(0.008),await(0.008),venture(0.008),lead(0.008)
# Topic 47 : tile(0.059),yeah(0.051),kind(0.036),think(0.027),talk(0.025),give(0.023),product(0.023),tool(0.021),dice(0.020),start(0.019),sort(0.018),matter(0.015),mean(0.015),okay(0.014),chamber(0.014),shop(0.014),real(0.013),maybe(0.012),tray(0.012),option(0.012),mega(0.012),food(0.011),exciting(0.009),component(0.009),single(0.008)
# Topic 48 : battle(0.024),army(0.024),race(0.023),rule(0.022),miniature(0.018),adventure(0.017),magic(0.015),force(0.015),suit(0.011),begin(0.010),fall(0.010),human(0.010),route(0.010),curse(0.009),reach(0.009),wizard(0.009),gain(0.008),advantage(0.008),undead(0.008),path(0.008),trap(0.008),cast(0.008),fight(0.008),special(0.008),defeat(0.007)
# Topic 49 : life(0.024),source(0.022),fracture(0.017),conversation(0.016),perfect(0.016),calendar(0.016),follow(0.014),glitch(0.013),shape(0.013),express(0.013),career(0.013),fact(0.013),flux(0.013),path(0.011),device(0.011),activity(0.011),enneagram(0.011),share(0.011),narrative(0.009),individual(0.009),meaningful(0.009),identify(0.008),survive(0.008),document(0.008),understanding(0.008)

# %%
# Unsupervised Analysis
model = non_guided_analysis(X, 50)
retrieve_words_from(model, vocab, 50, TOP_K_WORDS)
# Out:
# INFO:guidedlda:n_documents: 412
# INFO:guidedlda:vocab_size: 7526
# INFO:guidedlda:n_words: 49869
# INFO:guidedlda:n_topics: 50
# INFO:guidedlda:n_iter: 200
# INFO:guidedlda:<0> log likelihood: -734649
# INFO:guidedlda:<20> log likelihood: -443446
# INFO:guidedlda:<40> log likelihood: -434995
# INFO:guidedlda:<60> log likelihood: -429878
# INFO:guidedlda:<80> log likelihood: -427555
# INFO:guidedlda:<100> log likelihood: -424765
# INFO:guidedlda:<120> log likelihood: -424037
# INFO:guidedlda:<140> log likelihood: -422847
# INFO:guidedlda:<160> log likelihood: -422152
# INFO:guidedlda:<180> log likelihood: -421418
# INFO:guidedlda:<199> log likelihood: -420366
# Topic 0 : expansion(0.035),help(0.023),share(0.018),master(0.017),page(0.014),great(0.014),friend(0.013),tree(0.013),final(0.013),consequence(0.012),reach(0.012),offer(0.012),full(0.012),steal(0.010),gloom(0.010),wooden(0.010),follow(0.009),march(0.009),pledge(0.009),undead(0.009),come(0.009),core(0.008),suit(0.008),join(0.008),vampire(0.008)
# Topic 1 : thing(0.035),yeah(0.034),shirt(0.026),ninja(0.024),tell(0.019),good(0.018),mean(0.017),think(0.017),remember(0.016),important(0.015),storm(0.015),sign(0.013),actually(0.012),party(0.012),tear(0.012),hold(0.010),tonight(0.009),plan(0.009),happen(0.009),early(0.009),silly(0.007),pretty(0.007),judge(0.007),giant(0.007),introduce(0.007)
# Topic 2 : dice(0.026),thing(0.025),magical(0.024),access(0.023),thanks(0.017),tear(0.014),cast(0.014),spell(0.014),stretch(0.014),character(0.014),create(0.012),come(0.010),girl(0.010),system(0.010),rule(0.010),competition(0.010),soon(0.009),large(0.009),true(0.009),machine(0.009),item(0.009),ride(0.009),role(0.009),content(0.009),bring(0.009)
# Topic 3 : terrain(0.038),design(0.032),piece(0.031),movie(0.026),band(0.026),rock(0.022),meta(0.017),battle(0.015),variety(0.014),inside(0.014),battlefield(0.012),crowd(0.012),give(0.012),obstacle(0.011),plan(0.011),combination(0.011),builder(0.011),line(0.011),support(0.009),mullet(0.009),wayfarer(0.009),fast(0.009),appreciate(0.009),cross(0.009),bright(0.008)
# Topic 4 : enemy(0.056),boost(0.038),army(0.030),unit(0.027),attack(0.019),order(0.018),wall(0.016),feature(0.015),destroy(0.014),command(0.014),warlord(0.012),allow(0.012),strategy(0.011),product(0.011),defend(0.011),giant(0.011),resource(0.011),control(0.011),panda(0.011),nation(0.010),increase(0.010),enhance(0.010),takenoko(0.008),country(0.008),faction(0.008)
# Topic 5 : moon(0.035),build(0.031),galaxy(0.027),word(0.026),city(0.024),campaign(0.019),star(0.018),remain(0.016),sell(0.016),market(0.014),system(0.014),metaphor(0.014),edition(0.013),develop(0.013),step(0.011),galactic(0.011),building(0.010),strong(0.010),great(0.010),skirmish(0.010),minute(0.010),display(0.010),call(0.010),post(0.008),collection(0.008)
# Topic 6 : power(0.041),build(0.028),control(0.023),storm(0.022),gain(0.019),victory(0.019),open(0.016),combat(0.015),depth(0.014),damage(0.013),battle(0.013),island(0.013),content(0.013),ability(0.013),weapon(0.012),race(0.011),humanity(0.011),military(0.009),gameplay(0.009),city(0.009),strategic(0.009),equipment(0.008),strength(0.008),battlefield(0.008),purchase(0.008)
# Topic 7 : mean(0.026),physical(0.020),progress(0.017),follow(0.015),click(0.015),feel(0.014),entire(0.014),update(0.012),software(0.012),character(0.012),body(0.012),modifier(0.011),purpose(0.011),clear(0.011),classic(0.011),seal(0.011),house(0.009),attempt(0.009),individual(0.009),horror(0.009),control(0.009),lead(0.008),controller(0.008),solution(0.008),mount(0.008)
# Topic 8 : product(0.024),design(0.020),help(0.019),create(0.018),bring(0.018),support(0.018),share(0.018),experience(0.017),work(0.017),love(0.015),hope(0.014),board(0.013),excite(0.013),campaign(0.013),build(0.013),back(0.013),great(0.012),show(0.012),tabletop(0.011),watch(0.011),reward(0.010),video(0.010),launch(0.010),thank(0.010),come(0.010)
# Topic 9 : video(0.034),skill(0.027),people(0.026),start(0.025),thing(0.019),white(0.019),target(0.017),gold(0.016),board(0.016),look(0.015),pick(0.014),level(0.014),blue(0.014),collect(0.014),support(0.014),guild(0.013),black(0.013),quality(0.013),goods(0.011),craft(0.011),appreciate(0.011),model(0.011),camera(0.011),channel(0.010),reach(0.010)
# Topic 10 : kind(0.045),thing(0.033),think(0.027),come(0.025),people(0.024),character(0.024),start(0.023),love(0.022),story(0.020),actually(0.019),mean(0.017),idea(0.016),give(0.016),exciting(0.016),money(0.016),level(0.015),pretty(0.013),happen(0.012),part(0.010),basically(0.010),check(0.009),fight(0.009),item(0.008),feel(0.008),fantasy(0.008)
# Topic 11 : thing(0.027),help(0.022),great(0.021),support(0.020),hope(0.017),check(0.017),video(0.017),people(0.016),hear(0.016),give(0.015),back(0.015),work(0.015),board(0.014),mean(0.014),thank(0.013),bring(0.013),show(0.012),look(0.012),thanks(0.011),campaign(0.010),pick(0.010),wonderful(0.010),appreciate(0.010),find(0.010),reward(0.010)
# Topic 12 : card(0.055),battle(0.026),force(0.026),suit(0.019),realm(0.019),human(0.016),party(0.016),special(0.014),note(0.013),leave(0.012),primo(0.012),ticket(0.012),plan(0.012),fish(0.010),opponent(0.010),deck(0.010),look(0.010),show(0.010),regular(0.010),trap(0.010),kingdom(0.010),nameless(0.009),valhalla(0.009),give(0.007),move(0.007)
# Topic 13 : animal(0.025),race(0.021),save(0.020),ability(0.019),fight(0.019),technology(0.014),powerful(0.014),world(0.014),mission(0.014),protect(0.013),species(0.013),life(0.013),alien(0.013),quickly(0.013),human(0.013),experience(0.011),city(0.011),corner(0.009),rescue(0.009),trap(0.009),track(0.009),endless(0.009),leave(0.008),draw(0.008),combination(0.008)
# Topic 14 : shadow(0.044),witness(0.042),mystery(0.033),category(0.030),magic(0.018),design(0.018),leave(0.016),relic(0.016),sleeve(0.016),opportunity(0.014),artist(0.014),sundown(0.012),amazing(0.012),send(0.011),clue(0.011),ultra(0.009),believer(0.009),head(0.009),commission(0.009),favorite(0.009),week(0.009),alter(0.009),wolfbane(0.009),spirit(0.009),worry(0.009)
# Topic 15 : card(0.072),point(0.034),turn(0.029),move(0.028),back(0.020),action(0.019),come(0.019),board(0.017),draw(0.016),token(0.016),allow(0.016),rule(0.014),pick(0.013),place(0.012),lose(0.012),start(0.012),hand(0.011),give(0.010),choose(0.010),collect(0.010),number(0.009),tell(0.009),deck(0.009),part(0.009),color(0.009)
# Topic 16 : thank(0.031),community(0.028),copy(0.026),work(0.024),place(0.024),location(0.023),look(0.022),person(0.017),order(0.017),turn(0.015),find(0.014),stand(0.012),link(0.012),fill(0.011),direction(0.011),follow(0.010),object(0.010),line(0.010),lean(0.009),long(0.009),morning(0.009),ready(0.009),reality(0.008),hand(0.008),achieve(0.008)
# Topic 17 : world(0.044),work(0.030),create(0.026),team(0.023),call(0.018),system(0.017),experience(0.013),narrative(0.013),gameplay(0.013),explore(0.012),base(0.012),story(0.011),early(0.011),element(0.011),home(0.011),level(0.010),release(0.010),love(0.010),combine(0.009),character(0.009),mind(0.009),specifically(0.009),copy(0.008),life(0.008),concept(0.007)
# Topic 18 : world(0.044),create(0.036),unique(0.020),setting(0.016),secret(0.014),strategy(0.012),podcast(0.012),combat(0.012),bring(0.012),power(0.011),faction(0.011),fantasy(0.010),discover(0.010),dark(0.010),fracture(0.009),core(0.009),epic(0.009),content(0.009),light(0.009),heart(0.009),plan(0.009),action(0.009),early(0.009),stretch(0.009),fall(0.009)
# Topic 19 : material(0.026),dice(0.024),give(0.020),core(0.019),potion(0.018),level(0.017),craft(0.014),step(0.013),hand(0.013),side(0.013),front(0.012),activity(0.012),half(0.012),provide(0.012),high(0.011),city(0.011),positive(0.011),positivity(0.011),join(0.011),find(0.011),production(0.010),inch(0.010),custom(0.010),easy(0.010),double(0.009)
# Topic 20 : token(0.051),cave(0.040),chamber(0.022),dragon(0.022),crystal(0.021),night(0.019),rule(0.019),goblin(0.018),turn(0.017),order(0.015),field(0.015),represent(0.014),thief(0.014),video(0.012),option(0.011),vast(0.011),piece(0.011),dryad(0.011),tribe(0.010),movement(0.010),talk(0.010),remove(0.010),cube(0.008),design(0.008),objective(0.008)
# Topic 21 : opponent(0.027),turn(0.025),team(0.025),easy(0.022),unique(0.019),attack(0.019),family(0.019),choose(0.018),master(0.015),learn(0.014),building(0.013),experience(0.012),expansion(0.011),welcome(0.011),send(0.011),create(0.011),minute(0.010),competitive(0.010),arena(0.010),complete(0.009),member(0.009),control(0.009),read(0.008),cooperative(0.008),victory(0.008)
# Topic 22 : friend(0.036),people(0.035),come(0.035),look(0.026),give(0.024),actually(0.020),find(0.016),meet(0.015),video(0.014),stuff(0.013),live(0.013),start(0.012),good(0.011),event(0.011),yeah(0.011),group(0.011),work(0.011),tell(0.011),convention(0.010),super(0.010),sure(0.009),maybe(0.009),place(0.009),host(0.009),think(0.008)
# Topic 23 : character(0.102),level(0.030),point(0.026),weapon(0.021),story(0.020),represent(0.020),item(0.018),chicken(0.017),race(0.016),kill(0.016),base(0.015),grow(0.013),session(0.012),beat(0.012),magic(0.012),power(0.011),skill(0.011),follower(0.010),sheet(0.010),gain(0.010),stuff(0.010),throne(0.010),attack(0.010),class(0.010),wizard(0.010)
# Topic 24 : great(0.034),creature(0.027),find(0.025),land(0.024),unique(0.022),hero(0.019),call(0.019),style(0.016),imagine(0.016),look(0.015),place(0.015),turn(0.014),water(0.013),side(0.013),ground(0.012),kind(0.011),matter(0.010),lose(0.010),match(0.010),trip(0.010),design(0.010),creative(0.009),begin(0.009),grow(0.009),middle(0.008)
# Topic 25 : store(0.039),power(0.035),community(0.032),company(0.027),actually(0.024),break(0.022),ally(0.018),world(0.018),hero(0.017),fight(0.017),exactly(0.015),victory(0.015),leader(0.014),important(0.011),lgbtq(0.011),love(0.011),willing(0.010),flapjack(0.010),battle(0.010),sasquatch(0.008),floor(0.008),axis(0.008),fourth(0.008),france(0.008),today(0.008)
# Topic 26 : spell(0.028),block(0.027),damage(0.021),work(0.020),storytelling(0.019),doodle(0.019),wood(0.016),challenge(0.016),level(0.015),magic(0.015),monster(0.015),sword(0.014),adventure(0.014),search(0.013),defeat(0.013),weapon(0.013),encounter(0.013),wait(0.013),quick(0.012),edition(0.012),attack(0.011),basic(0.011),physical(0.009),erase(0.009),easier(0.009)
# Topic 27 : story(0.027),come(0.026),book(0.023),world(0.021),city(0.017),high(0.014),defeat(0.014),villain(0.014),save(0.012),lose(0.012),wish(0.011),evil(0.011),provide(0.011),detail(0.011),fight(0.011),mythology(0.011),elder(0.009),collection(0.009),palace(0.009),deep(0.009),folk(0.009),claim(0.009),dice(0.008),original(0.008),fiction(0.008)
# Topic 28 : adventure(0.031),island(0.027),forest(0.024),area(0.022),tree(0.020),color(0.018),tell(0.017),hill(0.017),long(0.015),cook(0.014),white(0.014),shrine(0.014),meal(0.013),beast(0.013),customer(0.013),larger(0.011),bird(0.011),land(0.011),hide(0.011),bear(0.011),black(0.010),pick(0.010),reward(0.008),great(0.008),unlock(0.008)
# Topic 29 : card(0.198),table(0.031),face(0.024),hand(0.021),round(0.021),wild(0.019),deck(0.017),friend(0.014),start(0.014),turn(0.013),super(0.013),fast(0.011),flip(0.011),action(0.010),grab(0.010),total(0.010),solution(0.009),rotten(0.009),stack(0.008),draw(0.008),easy(0.008),adult(0.008),paced(0.008),watch(0.008),pile(0.008)
# Topic 30 : card(0.110),friend(0.031),boss(0.027),family(0.024),money(0.017),strategy(0.016),work(0.016),creator(0.016),type(0.016),support(0.014),high(0.014),good(0.013),simple(0.013),order(0.012),martin(0.012),night(0.011),wall(0.011),respect(0.010),free(0.009),meme(0.009),earn(0.009),spend(0.009),finally(0.008),mafioso(0.008),favorite(0.008)
# Topic 31 : yeah(0.070),think(0.034),table(0.027),okay(0.027),thousand(0.024),hundred(0.022),good(0.019),million(0.018),back(0.017),painting(0.017),money(0.016),sell(0.015),night(0.014),collector(0.014),show(0.014),score(0.014),taste(0.011),start(0.010),artwork(0.010),credit(0.008),leave(0.008),critic(0.008),definitely(0.008),deal(0.008),pretty(0.008)
# Topic 32 : ship(0.058),crew(0.044),thing(0.026),cannon(0.026),captain(0.022),pirate(0.020),song(0.020),ravenscroft(0.018),nurse(0.014),move(0.014),cannonball(0.012),member(0.012),plank(0.012),hopefully(0.012),sail(0.012),gunpowder(0.012),state(0.010),family(0.010),bilge(0.010),pump(0.010),flood(0.008),harbor(0.008),bandmate(0.008),world(0.008),protect(0.008)
# Topic 33 : artist(0.045),world(0.030),digital(0.022),event(0.020),life(0.019),paint(0.019),manage(0.015),henry(0.015),stage(0.015),personal(0.015),sovereign(0.014),beautiful(0.012),career(0.012),artwork(0.012),raise(0.012),republican(0.011),follow(0.011),common(0.011),easy(0.010),mind(0.010),source(0.010),today(0.010),canvas(0.010),trio(0.008),head(0.008)
# Topic 34 : book(0.031),system(0.029),help(0.025),role(0.020),adventure(0.018),school(0.017),people(0.017),build(0.016),bring(0.015),rule(0.015),skill(0.015),dream(0.013),space(0.013),amazing(0.013),love(0.013),class(0.012),feel(0.012),experience(0.012),social(0.012),child(0.011),guide(0.011),thing(0.011),learn(0.010),work(0.010),part(0.009)
# Topic 35 : monster(0.084),book(0.035),campaign(0.027),creature(0.025),help(0.025),unicorn(0.021),test(0.018),dungeon(0.018),fight(0.017),role(0.016),write(0.015),dark(0.015),character(0.013),expand(0.013),survive(0.013),town(0.012),find(0.012),dragon(0.011),face(0.010),tier(0.010),horror(0.010),society(0.010),special(0.009),rescue(0.009),wizard(0.009)
# Topic 36 : earth(0.035),world(0.035),planet(0.022),explore(0.020),begin(0.020),space(0.019),quest(0.014),land(0.014),king(0.014),ship(0.013),colony(0.012),resource(0.011),energy(0.011),epic(0.011),path(0.010),welcome(0.010),choice(0.009),empire(0.009),reach(0.009),journey(0.009),route(0.008),dorado(0.008),exploration(0.008),lord(0.008),help(0.008)
# Topic 37 : people(0.041),challenge(0.032),thing(0.028),help(0.027),drink(0.021),point(0.019),brain(0.018),love(0.018),support(0.015),call(0.015),domino(0.014),parent(0.013),event(0.012),free(0.012),young(0.010),develop(0.010),give(0.010),round(0.010),hard(0.010),engage(0.010),hope(0.009),build(0.009),entire(0.009),connection(0.009),pull(0.009)
# Topic 38 : dice(0.039),back(0.033),roll(0.029),help(0.021),come(0.020),fund(0.017),world(0.017),work(0.015),call(0.015),decide(0.015),base(0.015),check(0.015),think(0.012),okay(0.012),final(0.012),talk(0.011),night(0.010),start(0.010),finish(0.010),head(0.009),hope(0.009),welcome(0.009),guess(0.009),choose(0.009),quick(0.008)
# Topic 39 : sport(0.031),fantasy(0.030),heart(0.021),join(0.018),deluxe(0.018),inspire(0.015),score(0.014),half(0.013),provide(0.013),child(0.013),food(0.012),campaign(0.012),today(0.012),backer(0.011),movie(0.008),quest(0.008),watch(0.008),wood(0.008),baby(0.008),size(0.008),offer(0.008),show(0.008),friend(0.007),woman(0.007),fully(0.007)
# Topic 40 : create(0.032),card(0.030),thank(0.021),come(0.021),start(0.020),look(0.020),check(0.019),section(0.018),thing(0.013),part(0.013),image(0.013),tarot(0.013),base(0.013),read(0.012),cover(0.011),stamp(0.010),forever(0.010),bunch(0.009),oracle(0.009),mine(0.008),basis(0.008),passion(0.008),exactly(0.008),prepare(0.008),long(0.008)
# Topic 41 : card(0.187),deck(0.091),draw(0.027),number(0.019),choose(0.018),design(0.018),base(0.014),hand(0.013),price(0.012),today(0.012),good(0.011),back(0.010),option(0.009),type(0.009),pack(0.008),beautiful(0.008),produce(0.008),gameplay(0.008),aspect(0.008),hundred(0.008),unique(0.008),shape(0.007),sure(0.007),meaning(0.007),king(0.007)
# Topic 42 : pool(0.037),cover(0.032),attach(0.024),lose(0.024),enjoy(0.021),ready(0.019),basketball(0.018),party(0.016),sheep(0.016),shot(0.016),keeper(0.016),ball(0.016),flock(0.015),find(0.013),golf(0.013),easily(0.013),remove(0.011),start(0.011),field(0.011),ride(0.010),market(0.010),easter(0.008),basket(0.008),theme(0.008),accessory(0.008)
# Topic 43 : puzzle(0.067),ninja(0.036),escape(0.034),room(0.033),back(0.026),match(0.025),flip(0.020),call(0.018),pass(0.018),piece(0.018),samurai(0.016),burrito(0.015),drawer(0.011),wound(0.011),help(0.011),discard(0.011),katana(0.011),remember(0.011),prison(0.011),hall(0.010),space(0.010),wood(0.008),kind(0.008),solve(0.008),advance(0.008)
# Topic 44 : bird(0.026),bring(0.025),space(0.023),area(0.017),tell(0.017),season(0.014),world(0.014),light(0.012),equipment(0.012),enjoy(0.012),real(0.012),street(0.012),rate(0.011),calendar(0.011),life(0.011),walk(0.011),backyard(0.011),custom(0.010),session(0.010),free(0.008),live(0.008),room(0.008),current(0.008),local(0.008),catch(0.008)
# Topic 45 : business(0.031),major(0.027),party(0.018),life(0.015),finish(0.014),dead(0.014),kitty(0.013),love(0.012),sure(0.012),work(0.012),learn(0.012),birthday(0.012),ship(0.012),size(0.012),famous(0.012),sort(0.010),country(0.010),american(0.010),state(0.010),good(0.010),island(0.009),happy(0.009),adult(0.009),head(0.009),funny(0.009)
# Topic 46 : create(0.043),come(0.026),question(0.026),thank(0.024),help(0.023),learn(0.019),watch(0.019),computer(0.016),page(0.015),idea(0.014),creator(0.014),person(0.014),share(0.013),stretch(0.012),science(0.012),home(0.011),answer(0.011),starter(0.010),basic(0.010),reach(0.010),main(0.009),process(0.009),complete(0.009),receive(0.009),enemy(0.008)
# Topic 47 : tile(0.104),board(0.031),move(0.026),place(0.024),tool(0.018),device(0.016),sort(0.015),table(0.014),side(0.014),back(0.014),mega(0.013),learn(0.012),wind(0.012),earn(0.012),addition(0.011),bike(0.009),gain(0.009),single(0.009),track(0.009),base(0.008),plan(0.008),glitch(0.008),feedback(0.007),return(0.007),valley(0.007)
# Topic 48 : dice(0.039),dungeon(0.029),stuff(0.028),adventure(0.028),look(0.023),pledge(0.023),miniature(0.021),cool(0.018),back(0.017),table(0.017),thing(0.016),battle(0.015),hold(0.014),inside(0.014),gear(0.013),side(0.013),couple(0.013),puzzle(0.012),edition(0.012),master(0.012),digital(0.011),rule(0.011),standard(0.010),tell(0.010),maze(0.009)
# Topic 49 : design(0.033),kind(0.033),people(0.032),think(0.026),idea(0.026),family(0.025),word(0.020),talk(0.020),source(0.018),find(0.015),human(0.014),perfect(0.013),group(0.013),research(0.012),decide(0.012),issue(0.011),series(0.009),matter(0.009),problem(0.008),list(0.008),sort(0.008),history(0.007),modern(0.007),promise(0.007),hard(0.007)
